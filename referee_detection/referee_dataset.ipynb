# %%
import argparse
import os
import sys
import tempfile
from pathlib import Path

import cv2
import h5py
import numpy as np
from naoth.log import BoundingBox
from tqdm import tqdm

tools_path = "../"
sys.path.append(tools_path)
print(sys.path)

from tools import (
    download_from_minio,
    get_labelstudio_client,
    get_minio_client,
    get_postgres_cursor,
    load_image_as_yuv422_y_only_pil,
)
# Out:
# ['/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/home/stella/robocup/naoth-deeplearning/venv_tf/lib/python3.10/site-packages', '../']

# %%
def download_images_and_masks():
    sql_query = f"""SELECT ls_project_top, bucket_top FROM robot_logs WHERE ls_project_top::int = 469"""
    print(sql_query)
    pg_cur = get_postgres_cursor()
    pg_cur.execute(sql_query)
    rtn_val = pg_cur.fetchall()
    data = [x for x in rtn_val]

    mclient = get_minio_client()
    ls = get_labelstudio_client()
    print(data)
    for ls_prj, bucket_name in sorted(data):

        print(f"Working on project {ls_prj}")

        project = ls.get_project(ls_prj)
        tasks = project.get_labeled_tasks()

        # TODO download all files for a project
        # TODO move the files inside an h5 file in the current folder
        # TODO think about structure inside h5 file
        # TODO first draft I can make mask from bounding boxes like this: https://stackoverflow.com/questions/64195636/converting-bounding-box-regions-into-masks-and-saving-them-as-png-files

        download_folder = Path("./datasets")
        download_folder_images = download_folder / "images"
        Path(download_folder).mkdir(exist_ok=True, parents=True)
        for task_output in tasks:
            # label part 1
            #print(task_output)
            for anno in task_output["annotations"]:
                results = anno["result"]
                for result in results:
                    # ignore relations here
                    if result["type"] != "rectanglelabels":
                        continue
                    
                    actual_label = result["value"]["rectanglelabels"][0]
                    if not actual_label == "referee":
                        continue
                    # x,y,width,height are all percentages within [0,100]
                    x, y, width, height = (
                        result["value"]["x"],
                        result["value"]["y"],
                        result["value"]["width"],
                        result["value"]["height"],
                    )
                    img_width = result["original_width"]
                    img_height = result["original_height"]
                    # FIXME int might not be the best rounding method here - but off by one pixel is also not that bad
                    x_px = int(x / 100 * img_width)
                    y_px = int(y / 100 * img_height)
                    width_px = int(width / 100 * img_width)
                    height_px = int(height / 100 * img_height)
                    print(task_output, width_px, height_px)
                    # crop_img = img[top_left_y : bottom_right_y, top_left_x : bottom_right_x]
                    image_file_name = task_output["storage_filename"]
                    image_path = download_from_minio(
                        client=mclient,
                        bucket_name=bucket_name,
                        filename=image_file_name,
                        output_folder=download_folder_images,
                    )
                    img = cv2.imread(str(image_path))
                    crop_img = img[y_px : y_px + height_px, x_px : x_px + width_px]
                    output_name = Path(download_folder_images) / image_file_name
                    cv2.imwrite(str(output_name), crop_img)

# %%
download_images_and_masks()
# Out:
# SELECT ls_project_top, bucket_top FROM robot_logs WHERE ls_project_top::int = 469
# [('469', 'fgbkngldutvkadpaxzwpjy')]
# Working on project 469
# {'id': 152748, 'predictions': [], 'annotations': [{'id': 106679, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'FmdoTeSjVg', 'type': 'rectanglelabels', 'value': {'x': 62.87425149700595, 'y': 29.94011976047902, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:04.669180Z', 'updated_at': '2024-07-16T12:45:39.750184Z', 'draft_created_at': None, 'lead_time': 1420.5700000000002, 'import_id': None, 'last_action': None, 'task': 152748, 'project': 469, 'updated_by': 1, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 10, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:04.669180Z', 'annotations_results': '[{id:FmdoTeSjVg, type:rectanglelabels, value:{x:62.87, y:29.94, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160107.png', 'annotations_ids': '106679', 'predictions_model_versions': '', 'avg_lead_time': 1420.5700000000002, 'draft_exists': False, 'updated_by': [{'user_id': 1}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152748/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMDcucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:41.709367Z', 'updated_at': '2024-07-16T12:45:40.421317Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# File datasets/images/fgbkngldutvkadpaxzwpjy_0160107.png already exists. Skipping download...
# {'id': 152749, 'predictions': [], 'annotations': [{'id': 106681, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': '-pY-ll0xv9', 'type': 'rectanglelabels', 'value': {'x': 62.57485029940116, 'y': 29.341317365269443, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:05.933594Z', 'updated_at': '2024-07-15T08:18:01.741898Z', 'draft_created_at': None, 'lead_time': 7.857, 'import_id': None, 'last_action': None, 'task': 152749, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 11, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:05.933594Z', 'annotations_results': '[{id:-pY-ll0xv9, type:rectanglelabels, value:{x:62.57, y:29.34, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160110.png', 'annotations_ids': '106681', 'predictions_model_versions': '', 'avg_lead_time': 7.857, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152749/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMTAucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:43.030241Z', 'updated_at': '2024-07-15T08:18:03.009996Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152750, 'predictions': [], 'annotations': [{'id': 106684, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'O8viYzFmZA', 'type': 'rectanglelabels', 'value': {'x': 61.976047904191574, 'y': 29.74051896207583, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:09.083457Z', 'updated_at': '2024-07-15T08:18:18.234800Z', 'draft_created_at': None, 'lead_time': 12.816, 'import_id': None, 'last_action': None, 'task': 152750, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 12, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:09.083457Z', 'annotations_results': '[{id:O8viYzFmZA, type:rectanglelabels, value:{x:61.98, y:29.74, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160114.png', 'annotations_ids': '106684', 'predictions_model_versions': '', 'avg_lead_time': 12.816, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152750/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMTQucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:43.178872Z', 'updated_at': '2024-07-15T08:18:18.647199Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152751, 'predictions': [], 'annotations': [{'id': 106686, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'PsST_6lFvm', 'type': 'rectanglelabels', 'value': {'x': 62.275449101796376, 'y': 29.14171656686625, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:10.849294Z', 'updated_at': '2024-07-15T08:18:27.040918Z', 'draft_created_at': None, 'lead_time': 6.188, 'import_id': None, 'last_action': None, 'task': 152751, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 13, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:10.849294Z', 'annotations_results': '[{id:PsST_6lFvm, type:rectanglelabels, value:{x:62.28, y:29.14, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160117.png', 'annotations_ids': '106686', 'predictions_model_versions': '', 'avg_lead_time': 6.188, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152751/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMTcucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:43.574025Z', 'updated_at': '2024-07-15T08:18:27.832799Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152752, 'predictions': [], 'annotations': [{'id': 106688, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'JzmAl_176G', 'type': 'rectanglelabels', 'value': {'x': 62.275449101796376, 'y': 29.540918163672636, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:13.089471Z', 'updated_at': '2024-07-15T08:18:38.474722Z', 'draft_created_at': None, 'lead_time': 7.021, 'import_id': None, 'last_action': None, 'task': 152752, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 14, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:13.089471Z', 'annotations_results': '[{id:JzmAl_176G, type:rectanglelabels, value:{x:62.28, y:29.54, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160120.png', 'annotations_ids': '106688', 'predictions_model_versions': '', 'avg_lead_time': 7.021, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152752/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMjAucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:44.503114Z', 'updated_at': '2024-07-15T08:18:40.048286Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152753, 'predictions': [], 'annotations': [{'id': 106691, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'g_lHV6W4eZ', 'type': 'rectanglelabels', 'value': {'x': 62.275449101796376, 'y': 29.341317365269443, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:19.651449Z', 'updated_at': '2024-07-15T08:18:48.040951Z', 'draft_created_at': None, 'lead_time': 5.043, 'import_id': None, 'last_action': None, 'task': 152753, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 15, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:19.651449Z', 'annotations_results': '[{id:g_lHV6W4eZ, type:rectanglelabels, value:{x:62.28, y:29.34, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160123.png', 'annotations_ids': '106691', 'predictions_model_versions': '', 'avg_lead_time': 5.043, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152753/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMjMucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:44.836091Z', 'updated_at': '2024-07-15T08:18:50.610044Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152754, 'predictions': [], 'annotations': [{'id': 189638, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '1\xa0month, 2\xa0weeks', 'completed_by': 2, 'result': [{'id': '29A8B2A26', 'type': 'rectanglelabels', 'value': {'x': 43.61173629760742, 'y': 58.3799680074056, 'width': 4.514265060424805, 'height': 9.602711995442709, 'rotation': 0, 'rectanglelabels': ['nao']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}, {'id': 'hKfcX5Gv22', 'type': 'rectanglelabels', 'value': {'x': 62.275449101796376, 'y': 29.341317365269443, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-06-01T19:09:52.885761Z', 'updated_at': '2024-07-15T08:18:58.904323Z', 'draft_created_at': None, 'lead_time': 2.47, 'import_id': None, 'last_action': None, 'task': 152754, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 16, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-06-01T19:09:52.885761Z', 'annotations_results': '[{id:29A8B2A26, type:rectanglelabels, value:{x:43.61, y:58.38, width:4.51, height:9.6, rotation:0, rectanglelabels:[nao]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480},{id:hKfcX5Gv22, type:rectanglelabels, value:{x:62.28, y:29.34, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640,', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160126.png', 'annotations_ids': '189638', 'predictions_model_versions': '', 'avg_lead_time': 2.47, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152754/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMjYucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:44.965300Z', 'updated_at': '2024-07-15T08:18:59.725182Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152755, 'predictions': [], 'annotations': [{'id': 106695, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'XHEpYbiJBP', 'type': 'rectanglelabels', 'value': {'x': 62.275449101796376, 'y': 29.341317365269443, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:23.579094Z', 'updated_at': '2024-07-15T08:19:06.117987Z', 'draft_created_at': None, 'lead_time': 3.367, 'import_id': None, 'last_action': None, 'task': 152755, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 17, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:23.579094Z', 'annotations_results': '[{id:XHEpYbiJBP, type:rectanglelabels, value:{x:62.28, y:29.34, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160129.png', 'annotations_ids': '106695', 'predictions_model_versions': '', 'avg_lead_time': 3.367, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152755/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMjkucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:45.019060Z', 'updated_at': '2024-07-15T08:19:07.736192Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152756, 'predictions': [], 'annotations': [{'id': 106697, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'x9lWb31vMl', 'type': 'rectanglelabels', 'value': {'x': 62.275449101796376, 'y': 29.341317365269443, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:24.805301Z', 'updated_at': '2024-07-15T08:19:13.913079Z', 'draft_created_at': None, 'lead_time': 3.416, 'import_id': None, 'last_action': None, 'task': 152756, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 18, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:24.805301Z', 'annotations_results': '[{id:x9lWb31vMl, type:rectanglelabels, value:{x:62.28, y:29.34, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160132.png', 'annotations_ids': '106697', 'predictions_model_versions': '', 'avg_lead_time': 3.416, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152756/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMzIucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:45.514234Z', 'updated_at': '2024-07-15T08:19:14.207139Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152757, 'predictions': [], 'annotations': [{'id': 106700, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': '7vstxZA6eR', 'type': 'rectanglelabels', 'value': {'x': 62.275449101796376, 'y': 29.341317365269443, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:29.812411Z', 'updated_at': '2024-07-15T08:19:20.154160Z', 'draft_created_at': None, 'lead_time': 2.817, 'import_id': None, 'last_action': None, 'task': 152757, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 19, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:29.812411Z', 'annotations_results': '[{id:7vstxZA6eR, type:rectanglelabels, value:{x:62.28, y:29.34, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160136.png', 'annotations_ids': '106700', 'predictions_model_versions': '', 'avg_lead_time': 2.817, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152757/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMzYucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:45.775741Z', 'updated_at': '2024-07-15T08:19:21.034305Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152758, 'predictions': [], 'annotations': [{'id': 106702, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'aIGXyNalu0', 'type': 'rectanglelabels', 'value': {'x': 62.275449101796376, 'y': 29.341317365269443, 'width': 10.479041916167683, 'height': 39.32135728542915, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:30.820563Z', 'updated_at': '2024-07-15T08:19:24.777332Z', 'draft_created_at': None, 'lead_time': 1.739, 'import_id': None, 'last_action': None, 'task': 152758, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 20, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:30.820563Z', 'annotations_results': '[{id:aIGXyNalu0, type:rectanglelabels, value:{x:62.28, y:29.34, width:10.48, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160139.png', 'annotations_ids': '106702', 'predictions_model_versions': '', 'avg_lead_time': 1.739, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152758/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxMzkucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:46.216661Z', 'updated_at': '2024-07-15T08:19:25.401533Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 67 188
# {'id': 152759, 'predictions': [], 'annotations': [{'id': 106704, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'L6oTJetexE', 'type': 'rectanglelabels', 'value': {'x': 61.6766467065868, 'y': 29.341317365269433, 'width': 12.724550898203566, 'height': 39.32135728542911, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:32.165039Z', 'updated_at': '2024-07-15T08:19:35.445442Z', 'draft_created_at': None, 'lead_time': 8.393, 'import_id': None, 'last_action': None, 'task': 152759, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 21, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:32.165039Z', 'annotations_results': '[{id:L6oTJetexE, type:rectanglelabels, value:{x:61.68, y:29.34, width:12.72, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160142.png', 'annotations_ids': '106704', 'predictions_model_versions': '', 'avg_lead_time': 8.393, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152759/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNDIucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:46.444181Z', 'updated_at': '2024-07-15T08:19:36.017525Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 81 188
# {'id': 152760, 'predictions': [], 'annotations': [{'id': 106706, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'K9Y9MwGkdH', 'type': 'rectanglelabels', 'value': {'x': 60.479041916167574, 'y': 29.341317365269422, 'width': 16.317365269461078, 'height': 39.3213572854291, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:40.082131Z', 'updated_at': '2024-07-15T08:19:54.346049Z', 'draft_created_at': None, 'lead_time': 9.493, 'import_id': None, 'last_action': None, 'task': 152760, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 22, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:40.082131Z', 'annotations_results': '[{id:K9Y9MwGkdH, type:rectanglelabels, value:{x:60.48, y:29.34, width:16.32, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160145.png', 'annotations_ids': '106706', 'predictions_model_versions': '', 'avg_lead_time': 9.493, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152760/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNDUucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:46.572658Z', 'updated_at': '2024-07-15T08:19:57.560309Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 104 188
# {'id': 152761, 'predictions': [], 'annotations': [{'id': 106709, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'ZjhpiMHc-H', 'type': 'rectanglelabels', 'value': {'x': 58.982035928143674, 'y': 29.341317365269376, 'width': 20.20958083832327, 'height': 39.32135728542903, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:43.265726Z', 'updated_at': '2024-07-15T08:20:06.470368Z', 'draft_created_at': None, 'lead_time': 6.619, 'import_id': None, 'last_action': None, 'task': 152761, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 23, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:43.265726Z', 'annotations_results': '[{id:ZjhpiMHc-H, type:rectanglelabels, value:{x:58.98, y:29.34, width:20.21, height:39.32, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160148.png', 'annotations_ids': '106709', 'predictions_model_versions': '', 'avg_lead_time': 6.619, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152761/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNDgucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:46.937709Z', 'updated_at': '2024-07-15T08:20:06.965788Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 129 188
# {'id': 152762, 'predictions': [], 'annotations': [{'id': 106711, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'zbsUQKcBE2', 'type': 'rectanglelabels', 'value': {'x': 59.13173652694604, 'y': 27.14570858283425, 'width': 20.059880239520915, 'height': 41.51696606786425, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:44.436896Z', 'updated_at': '2024-07-15T08:20:16.446063Z', 'draft_created_at': None, 'lead_time': 7.205, 'import_id': None, 'last_action': None, 'task': 152762, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 24, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:44.436896Z', 'annotations_results': '[{id:zbsUQKcBE2, type:rectanglelabels, value:{x:59.13, y:27.15, width:20.06, height:41.52, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160152.png', 'annotations_ids': '106711', 'predictions_model_versions': '', 'avg_lead_time': 7.205, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152762/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNTIucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.162538Z', 'updated_at': '2024-07-15T08:20:17.305879Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 128 199
# {'id': 152763, 'predictions': [], 'annotations': [{'id': 106713, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'sAJbbI_Ly4', 'type': 'rectanglelabels', 'value': {'x': 60.17964071856279, 'y': 23.552894211576827, 'width': 17.514970059880277, 'height': 45.109780439121685, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:48.315080Z', 'updated_at': '2024-07-15T08:20:27.426586Z', 'draft_created_at': None, 'lead_time': 7.838, 'import_id': None, 'last_action': None, 'task': 152763, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 25, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:48.315080Z', 'annotations_results': '[{id:sAJbbI_Ly4, type:rectanglelabels, value:{x:60.18, y:23.55, width:17.51, height:45.11, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160155.png', 'annotations_ids': '106713', 'predictions_model_versions': '', 'avg_lead_time': 7.838, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152763/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNTUucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.190534Z', 'updated_at': '2024-07-15T08:20:27.967031Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 112 216
# {'id': 152764, 'predictions': [], 'annotations': [{'id': 106716, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'NQP2gxayut', 'type': 'rectanglelabels', 'value': {'x': 61.07784431137719, 'y': 21.95608782435127, 'width': 13.323353293413126, 'height': 46.70658682634729, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:50.379130Z', 'updated_at': '2024-07-15T08:20:37.272469Z', 'draft_created_at': None, 'lead_time': 6.475, 'import_id': None, 'last_action': None, 'task': 152764, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 26, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:50.379130Z', 'annotations_results': '[{id:NQP2gxayut, type:rectanglelabels, value:{x:61.08, y:21.96, width:13.32, height:46.71, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160158.png', 'annotations_ids': '106716', 'predictions_model_versions': '', 'avg_lead_time': 6.475, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152764/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNTgucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.223390Z', 'updated_at': '2024-07-15T08:20:38.206658Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 85 224
# {'id': 152765, 'predictions': [], 'annotations': [{'id': 106718, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': '8nTudPmyL6', 'type': 'rectanglelabels', 'value': {'x': 61.676646706586766, 'y': 22.954091816367235, 'width': 12.125748502993982, 'height': 45.708582834331295, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:51.423138Z', 'updated_at': '2024-07-15T08:20:48.238710Z', 'draft_created_at': None, 'lead_time': 8.656, 'import_id': None, 'last_action': None, 'task': 152765, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 27, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:51.423138Z', 'annotations_results': '[{id:8nTudPmyL6, type:rectanglelabels, value:{x:61.68, y:22.95, width:12.13, height:45.71, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160161.png', 'annotations_ids': '106718', 'predictions_model_versions': '', 'avg_lead_time': 8.656, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152765/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNjEucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.247011Z', 'updated_at': '2024-07-15T08:20:49.732792Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 77 219
# {'id': 152766, 'predictions': [], 'annotations': [{'id': 106720, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'q6HBQKFAf2', 'type': 'rectanglelabels', 'value': {'x': 61.67664670658678, 'y': 21.756487025948076, 'width': 11.676646706586824, 'height': 46.90618762475043, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:52.801633Z', 'updated_at': '2024-07-15T08:21:02.028994Z', 'draft_created_at': None, 'lead_time': 6.237, 'import_id': None, 'last_action': None, 'task': 152766, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 28, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:52.801633Z', 'annotations_results': '[{id:q6HBQKFAf2, type:rectanglelabels, value:{x:61.68, y:21.76, width:11.68, height:46.91, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160164.png', 'annotations_ids': '106720', 'predictions_model_versions': '', 'avg_lead_time': 6.237, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152766/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNjQucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.271195Z', 'updated_at': '2024-07-15T08:21:04.393717Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 74 225
# {'id': 152767, 'predictions': [], 'annotations': [{'id': 106722, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'P_fw1QiSV4', 'type': 'rectanglelabels', 'value': {'x': 61.67664670658676, 'y': 22.155688622754464, 'width': 11.227544910179658, 'height': 46.50698602794413, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:55.240335Z', 'updated_at': '2024-07-15T08:21:43.397392Z', 'draft_created_at': None, 'lead_time': 17.538, 'import_id': None, 'last_action': None, 'task': 152767, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 29, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:55.240335Z', 'annotations_results': '[{id:P_fw1QiSV4, type:rectanglelabels, value:{x:61.68, y:22.16, width:11.23, height:46.51, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160167.png', 'annotations_ids': '106722', 'predictions_model_versions': '', 'avg_lead_time': 17.538, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152767/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNjcucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.303939Z', 'updated_at': '2024-07-15T08:21:43.848683Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 71 223
# {'id': 152768, 'predictions': [], 'annotations': [{'id': 106725, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'WdEhEqstBn', 'type': 'rectanglelabels', 'value': {'x': 61.67664670658676, 'y': 22.155688622754464, 'width': 11.227544910179658, 'height': 46.50698602794413, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:58.232924Z', 'updated_at': '2024-07-15T08:21:50.681656Z', 'draft_created_at': None, 'lead_time': 2.343, 'import_id': None, 'last_action': None, 'task': 152768, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 30, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:58.232924Z', 'annotations_results': '[{id:WdEhEqstBn, type:rectanglelabels, value:{x:61.68, y:22.16, width:11.23, height:46.51, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160170.png', 'annotations_ids': '106725', 'predictions_model_versions': '', 'avg_lead_time': 2.343, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152768/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNzAucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.565287Z', 'updated_at': '2024-07-15T08:21:51.322376Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 71 223
# {'id': 152769, 'predictions': [], 'annotations': [{'id': 106727, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'gxPxAT2Mp-', 'type': 'rectanglelabels', 'value': {'x': 61.67664670658676, 'y': 22.155688622754464, 'width': 11.227544910179658, 'height': 46.50698602794413, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:23:59.245627Z', 'updated_at': '2024-07-15T08:21:57.949307Z', 'draft_created_at': None, 'lead_time': 2.685, 'import_id': None, 'last_action': None, 'task': 152769, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 31, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:23:59.245627Z', 'annotations_results': '[{id:gxPxAT2Mp-, type:rectanglelabels, value:{x:61.68, y:22.16, width:11.23, height:46.51, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160174.png', 'annotations_ids': '106727', 'predictions_model_versions': '', 'avg_lead_time': 2.685, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152769/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNzQucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.657022Z', 'updated_at': '2024-07-15T08:21:59.674125Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 71 223
# {'id': 152770, 'predictions': [], 'annotations': [{'id': 106729, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'pAVqDuCBjN', 'type': 'rectanglelabels', 'value': {'x': 61.67664670658676, 'y': 22.155688622754464, 'width': 11.227544910179658, 'height': 46.50698602794413, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:24:00.394599Z', 'updated_at': '2024-07-15T08:22:05.155979Z', 'draft_created_at': None, 'lead_time': 2.265, 'import_id': None, 'last_action': None, 'task': 152770, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 32, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:24:00.394599Z', 'annotations_results': '[{id:pAVqDuCBjN, type:rectanglelabels, value:{x:61.68, y:22.16, width:11.23, height:46.51, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160177.png', 'annotations_ids': '106729', 'predictions_model_versions': '', 'avg_lead_time': 2.265, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152770/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjAxNzcucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:50:47.883785Z', 'updated_at': '2024-07-15T08:22:07.662503Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 71 223
# ...
# {'id': 152890, 'predictions': [], 'annotations': [{'id': 107002, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'cHHQz3OWIx', 'type': 'rectanglelabels', 'value': {'x': 59.58083832335346, 'y': 21.35728542914156, 'width': 18.413173652694436, 'height': 47.305389221556624, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:29:42.547688Z', 'updated_at': '2024-07-15T10:17:47.120421Z', 'draft_created_at': None, 'lead_time': 11.704, 'import_id': None, 'last_action': None, 'task': 152890, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 152, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:29:42.547688Z', 'annotations_results': '[{id:cHHQz3OWIx, type:rectanglelabels, value:{x:59.58, y:21.36, width:18.41, height:47.31, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160552.png', 'annotations_ids': '107002', 'predictions_model_versions': '', 'avg_lead_time': 11.704, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152890/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjA1NTIucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:51:03.335507Z', 'updated_at': '2024-07-15T10:17:47.877478Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 117 227
# {'id': 152891, 'predictions': [], 'annotations': [{'id': 107004, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'ekVFS7PDrM', 'type': 'rectanglelabels', 'value': {'x': 59.58083832335346, 'y': 21.35728542914156, 'width': 18.413173652694436, 'height': 47.305389221556624, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:29:43.569778Z', 'updated_at': '2024-07-15T10:17:56.459923Z', 'draft_created_at': None, 'lead_time': 1.382, 'import_id': None, 'last_action': None, 'task': 152891, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 153, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:29:43.569778Z', 'annotations_results': '[{id:ekVFS7PDrM, type:rectanglelabels, value:{x:59.58, y:21.36, width:18.41, height:47.31, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160555.png', 'annotations_ids': '107004', 'predictions_model_versions': '', 'avg_lead_time': 1.382, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152891/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjA1NTUucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:51:03.371494Z', 'updated_at': '2024-07-15T10:17:57.445748Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 117 227
# {'id': 152892, 'predictions': [], 'annotations': [{'id': 107007, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'VOJpYgEEaR', 'type': 'rectanglelabels', 'value': {'x': 59.58083832335346, 'y': 21.35728542914156, 'width': 18.413173652694436, 'height': 47.305389221556624, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:29:50.189991Z', 'updated_at': '2024-07-15T10:18:00.898772Z', 'draft_created_at': None, 'lead_time': 1.02, 'import_id': None, 'last_action': None, 'task': 152892, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 154, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:29:50.189991Z', 'annotations_results': '[{id:VOJpYgEEaR, type:rectanglelabels, value:{x:59.58, y:21.36, width:18.41, height:47.31, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160558.png', 'annotations_ids': '107007', 'predictions_model_versions': '', 'avg_lead_time': 1.02, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152892/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjA1NTgucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:51:03.411861Z', 'updated_at': '2024-07-15T10:18:03.099450Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 117 227
# {'id': 152893, 'predictions': [], 'annotations': [{'id': 107009, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'ZY0lHKhMEU', 'type': 'rectanglelabels', 'value': {'x': 59.58083832335346, 'y': 21.35728542914156, 'width': 18.413173652694436, 'height': 47.305389221556624, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:29:51.268823Z', 'updated_at': '2024-07-15T10:18:06.748676Z', 'draft_created_at': None, 'lead_time': 0.783, 'import_id': None, 'last_action': None, 'task': 152893, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 155, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:29:51.268823Z', 'annotations_results': '[{id:ZY0lHKhMEU, type:rectanglelabels, value:{x:59.58, y:21.36, width:18.41, height:47.31, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160561.png', 'annotations_ids': '107009', 'predictions_model_versions': '', 'avg_lead_time': 0.783, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152893/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjA1NjEucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:51:03.468038Z', 'updated_at': '2024-07-15T10:18:08.282529Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 117 227
# {'id': 152894, 'predictions': [], 'annotations': [{'id': 107011, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'W4i1B5Yr_y', 'type': 'rectanglelabels', 'value': {'x': 59.58083832335346, 'y': 21.35728542914156, 'width': 18.413173652694436, 'height': 47.305389221556624, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:29:52.243433Z', 'updated_at': '2024-07-15T10:18:12.631583Z', 'draft_created_at': None, 'lead_time': 0.796, 'import_id': None, 'last_action': None, 'task': 152894, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 156, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:29:52.243433Z', 'annotations_results': '[{id:W4i1B5Yr_y, type:rectanglelabels, value:{x:59.58, y:21.36, width:18.41, height:47.31, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160565.png', 'annotations_ids': '107011', 'predictions_model_versions': '', 'avg_lead_time': 0.796, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152894/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjA1NjUucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:51:03.560472Z', 'updated_at': '2024-07-15T10:18:13.054783Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 117 227
# {'id': 152895, 'predictions': [], 'annotations': [{'id': 107013, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': 'WDZ-cEdt3c', 'type': 'rectanglelabels', 'value': {'x': 59.58083832335346, 'y': 21.35728542914156, 'width': 18.413173652694436, 'height': 47.305389221556624, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:29:54.931741Z', 'updated_at': '2024-07-15T10:18:15.816127Z', 'draft_created_at': None, 'lead_time': 0.931, 'import_id': None, 'last_action': None, 'task': 152895, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 157, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:29:54.931741Z', 'annotations_results': '[{id:WDZ-cEdt3c, type:rectanglelabels, value:{x:59.58, y:21.36, width:18.41, height:47.31, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160568.png', 'annotations_ids': '107013', 'predictions_model_versions': '', 'avg_lead_time': 0.931, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152895/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjA1NjgucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:51:03.609815Z', 'updated_at': '2024-07-15T10:18:16.487653Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 117 227
# {'id': 152896, 'predictions': [], 'annotations': [{'id': 107016, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': '1EuFJlnBPD', 'type': 'rectanglelabels', 'value': {'x': 59.58083832335346, 'y': 21.35728542914156, 'width': 18.413173652694436, 'height': 47.305389221556624, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:30:02.449585Z', 'updated_at': '2024-07-15T10:18:20.521996Z', 'draft_created_at': None, 'lead_time': 1.84, 'import_id': None, 'last_action': None, 'task': 152896, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 158, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:30:02.449585Z', 'annotations_results': '[{id:1EuFJlnBPD, type:rectanglelabels, value:{x:59.58, y:21.36, width:18.41, height:47.31, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160571.png', 'annotations_ids': '107016', 'predictions_model_versions': '', 'avg_lead_time': 1.84, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152896/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjA1NzEucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:51:03.631259Z', 'updated_at': '2024-07-15T10:18:21.246843Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 117 227
# {'id': 152897, 'predictions': [], 'annotations': [{'id': 107018, 'created_username': 'eliza bot bot@berlinunited.com, 2', 'created_ago': '2\xa0months, 3\xa0weeks', 'completed_by': 2, 'result': [{'id': '6YjIhMZcnL', 'type': 'rectanglelabels', 'value': {'x': 59.58083832335339, 'y': 22.754491017963915, 'width': 19.910179640718408, 'height': 45.90818363273427, 'rotation': 0, 'rectanglelabels': ['referee']}, 'origin': 'manual', 'to_name': 'image', 'from_name': 'label', 'image_rotation': 0, 'original_width': 640, 'original_height': 480}], 'was_cancelled': False, 'ground_truth': False, 'created_at': '2024-04-25T12:30:03.467656Z', 'updated_at': '2024-07-15T10:18:30.246290Z', 'draft_created_at': None, 'lead_time': 6.397, 'import_id': None, 'last_action': None, 'task': 152897, 'project': 469, 'updated_by': 5, 'parent_prediction': None, 'parent_annotation': None, 'last_created_by': None}], 'drafts': [], 'annotators': [2], 'inner_id': 159, 'cancelled_annotations': 0, 'total_annotations': 1, 'total_predictions': 0, 'completed_at': '2024-04-25T12:30:03.467656Z', 'annotations_results': '[{id:6YjIhMZcnL, type:rectanglelabels, value:{x:59.58, y:22.75, width:19.91, height:45.91, rotation:0, rectanglelabels:[referee]}, origin:manual, to_name:image, from_name:label, image_rotation:0, original_width:640, original_height:480}]', 'predictions_results': '', 'predictions_score': None, 'file_upload': None, 'storage_filename': '0160574.png', 'annotations_ids': '107018', 'predictions_model_versions': '', 'avg_lead_time': 6.397, 'draft_exists': False, 'updated_by': [{'user_id': 5}], 'data': {'image': 'https://ls.berlin-united.com/tasks/152897/presign/?fileuri=czM6Ly9mZ2JrbmdsZHV0dmthZHBheHp3cGp5LzAxNjA1NzQucG5n'}, 'meta': {}, 'created_at': '2024-04-24T11:51:03.684476Z', 'updated_at': '2024-07-15T10:18:30.827423Z', 'is_labeled': True, 'overlap': 1, 'comment_count': 0, 'unresolved_comment_count': 0, 'last_comment_updated_at': None, 'project': 469, 'comment_authors': []} 127 220
